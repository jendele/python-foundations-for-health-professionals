# %% [markdown]
# # Session 1 — Homework
#
# **Due:** Friday, 24 April 2026, 09:00 (start of Session 2)
# **Submission:** upload this notebook to eCampus.
# **Time budget:** 30–45 minutes.
#
# ---
#
# ## What you will practise
#
# - assigning variables
# - working with three small patient dictionaries
# - a clinical calculation (BMI) for each of them
# - a readable printout using f-strings
# - reflecting on what felt awkward or repetitive (important — we fix it in Session 2 and Session 3)
#
# ---
#
# **Your name:** _fill in_
# **Date worked on:** _fill in_

# %% [markdown]
# ## Task 1 — Three patients
#
# Below you find three patient dictionaries. Run the cell as is — no changes needed.

# %%
patient_1 = {"id": "P101", "name": "Mila Okoye",     "age": 42, "weight_kg": 68.0, "height_m": 1.65}
patient_2 = {"id": "P102", "name": "Jonas Krüger",   "age": 59, "weight_kg": 94.5, "height_m": 1.78}
patient_3 = {"id": "P103", "name": "Beatrice Rossi", "age": 33, "weight_kg": 55.2, "height_m": 1.71}

# %% [markdown]
# ## Task 2 — BMI for each patient
#
# For each of the three patients, compute their BMI and **print one clear line** in the format:
#
# ```
# Mila Okoye (ID P101): BMI = 25.0 kg/m^2
# ```
#
# Formula: `BMI = weight_kg / (height_m ** 2)`. Round the BMI to one decimal place.

# %%
# TODO: compute BMI for patient_1 and print the formatted line

# %%
# TODO: same for patient_2

# %%
# TODO: same for patient_3

# %% [markdown]
# ## Task 3 — Reflection (markdown answer, 3–5 sentences)
#
# In the next cell, answer in your own words:
#
# 1. What felt **repetitive** when you wrote the code for Task 2?
# 2. If I gave you 100 patients instead of 3, what would you *not* want to do by hand?
# 3. What did you google / ask an AI for? (No judgment — I just want to know where the friction was.)

# %% [markdown]
# _Your reflection here._

# %% [markdown]
# ## (Optional) Task 4 — Fast-Track
#
# If you got through Tasks 1–3 quickly: put the three patients into a **list** called `patients`, and use a `for` loop to print all three BMI lines without repeating yourself. This is exactly what we build in Session 2 — no need to finish it if it doesn't click yet.

# %%
# Optional: list + for loop
