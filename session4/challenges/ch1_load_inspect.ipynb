# %% [markdown]
# # Mini-Challenge 1 — Load & Inspect: Saint Mary's patient roster
# ### Saint Mary's · Thursday morning, 09:45
#
# > *"Here are 200 patients in our care. How many of them carry serious comorbidity load — meaning ≥ 2 chronic conditions?"*
#
# **Time:** 25 min · **Mode:** tandem · **Goal:** first-pass inspection of a real CSV.
#
# ---

# %% [markdown]
# ## Step 1 — Load the file

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Walk up to find the 'data/' folder — works from any notebook location
HERE = Path.cwd()
DATA = next((p / "data" for p in [HERE, *HERE.parents] if (p / "data").exists()), None)
assert DATA is not None, "data/ folder not found"
print("Using DATA =", DATA)

# %%
# TODO: load patients.csv into a DataFrame called `patients`
patients = ...   # replace this

# Quick check:
# print(type(patients))
# print(patients.shape)

# %% [markdown]
# ## Step 2 — Three first-look operations

# %%
# TODO: print the first 5 rows
# patients.head()

# TODO: print column names and dtypes
# patients.info()

# TODO: print a numeric summary
# patients.describe()

# %% [markdown]
# ## Step 3 — Count patients with ≥ 2 chronic conditions
#
# The `chronic_conditions` column is a string with conditions separated by `;` (or empty).
# A patient with `"diabetes_t2;hypertension"` has 2 conditions; an empty string means 0.

# %%
# TODO: build a new column 'chronic_count' that equals the number of conditions per patient.
# Hint: split on ";" and count, but careful — empty string would give 1 with naive split. Use:
#     patients["chronic_conditions"].fillna("").str.split(";").apply(lambda lst: 0 if lst == [""] else len(lst))

patients["chronic_count"] = ...   # replace this

# TODO: count patients with chronic_count >= 2 and print:
#   * how many
#   * what % of total

# %% [markdown]
# ## ⭐ Fast-Track — Comorbidity rate per insurance

# %%
# TODO: For each insurance type, compute:
#   * the average chronic_count
#   * the % of patients with chronic_count >= 2
# Print the result sorted from highest comorbidity-rate to lowest.

# Hint: groupby("primary_insurance").agg(...).
# We will see groupby fully tomorrow — try it now.
