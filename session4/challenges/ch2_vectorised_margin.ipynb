# %% [markdown]
# # Mini-Challenge 2 — Margin per case, the vectorised way
# ### Saint Mary's · Thursday morning, 11:00
#
# > *"For all 320 encounters, compute the margin (DRG reimbursement minus actual cost) per case. **No Python for-loop**. Total margin and number of loss-making cases on my desk."*
#
# **Time:** 25 min · **Mode:** tandem · **Goal:** practise vectorised arithmetic on real data.
#
# ---

# %% [markdown]
# ## Step 1 — Load encounters and DRG catalog

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Walk up to find the 'data/' folder — works from any notebook location
HERE = Path.cwd()
DATA = next((p / "data" for p in [HERE, *HERE.parents] if (p / "data").exists()), None)
assert DATA is not None, "data/ folder not found"
print("Using DATA =", DATA)

# %%
# TODO: load encounters.csv → `enc`
# TODO: load drg_catalog.csv → `drg`

enc = ...
drg = ...
print("encounters:", enc.shape, "| drg:", drg.shape)

# %% [markdown]
# ## Step 2 — Join the reimbursement onto each encounter

# %%
# TODO: merge enc and drg on the column 'drg_code' (left join).
# After merge, every encounter row should have a 'base_reimbursement_eur' column.

enc = ...   # replace this
print(enc.columns.tolist())
enc.head(3)

# %% [markdown]
# ## Step 3 — Compute margin (vectorised)

# %%
# TODO: add a new column 'margin_eur' = base_reimbursement_eur - actual_cost_eur.
# This must be ONE expression. No for-loop.

# enc["margin_eur"] = ...

# Then print:
#   * total margin (sum)
#   * number of loss-making cases (margin < 0)

# %% [markdown]
# ## ⭐ Fast-Track — Top 3 loss-making DRGs

# %%
# TODO: among loss-making cases, find the 3 DRG codes with the WORST total margin (most negative sum).
# Print code, label, count, total margin.
# Hint: groupby + agg + sort_values.
