# %% [markdown]
# # Session 2 — Homework
#
# **Due:** Wednesday, 06 May 2026, 09:00 (start of Session 3)
# **Submission:** upload this notebook to eCampus.
# **Time budget:** 45–60 minutes.
#
# ---
#
# ## What you will practise
#
# - writing `if` / `elif` / `else` against clinical thresholds
# - iterating over a list with a `for` loop
# - aggregating a simple count
# - filtering a list (for the mean calculation)
# - using (or at least recognising) a list comprehension
#
# ---
#
# **Your name:** _fill in_
# **Date worked on:** _fill in_

# %% [markdown]
# ## The data
#
# Ten body temperatures in degrees Celsius. Run this cell as is.

# %%
temperatures = [35.2, 36.1, 36.8, 37.0, 37.3, 37.6, 38.2, 38.9, 39.4, 40.1]

# %% [markdown]
# ## The classification rule
#
# | Category | Rule |
# |---|---|
# | `hypothermia` | t < 36 |
# | `normal` | 36 ≤ t ≤ 37.5 |
# | `fever` | 37.5 < t ≤ 39 |
# | `high fever` | t > 39 |
#
# Note the inclusive/exclusive boundaries carefully.

# %% [markdown]
# ## Task 1 — Classify each temperature
#
# Write a `for` loop that goes through `temperatures`. For each value, print a line like:
#
# ```
# 36.1 °C → normal
# 38.2 °C → fever
# ```

# %%
# TODO: loop + if/elif/else + print

# %% [markdown]
# ## Task 2 — Count how many in each category
#
# Build a `counts` dictionary with the four categories as keys. At the end, print the dictionary.

# %%
# TODO: counts dict + loop + category increment

# %% [markdown]
# ## Task 3 — Mean temperature of the feverish readings
#
# Compute the **mean** of only those temperatures that are strictly greater than 37.5. Print the result rounded to two decimal places.
#
# Hint: you can filter with a list comprehension `[t for t in temperatures if t > 37.5]`, or with a classic loop — your choice.

# %%
# TODO: filter + mean + formatted print

# %% [markdown]
# ## Task 4 — Reflection (markdown, 3–5 sentences)
#
# Where did you use (or where *could you have used*) a **list comprehension** in this homework? Paste the line you wrote or would have written. If you didn't use one, explain why a classic loop felt easier — that is a fine answer and I want to know.

# %% [markdown]
# _Your reflection here._
