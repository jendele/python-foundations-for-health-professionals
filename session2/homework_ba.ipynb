# %% [markdown]
# # Session 2 — Homework (Business Analytics track)
#
# **Due:** Wednesday, 06 May 2026, 09:00 (start of Session 3)
# **Submission:** upload this notebook to eCampus.
# **Time budget:** 45–60 minutes.
#
# ---
#
# ## What you will practise
#
# - writing `if` / `elif` / `else` against business thresholds
# - iterating over a list with a `for` loop
# - aggregating a simple count
# - filtering a list (for the mean calculation)
# - using (or at least recognising) a list comprehension
#
# ---
#
# **Your name:** _fill in_
# **Date worked on:** _fill in_

# %% [markdown]
# ## The data
#
# Ten customer order values from an online shop, in euros. Run this cell as is.

# %%
order_values = [12.50, 27.80, 45.00, 99.90, 150.00, 189.75, 329.00, 475.50, 612.00, 1250.00]

# %% [markdown]
# ## The segmentation rule
#
# Your marketing team wants every incoming order tagged into one of four customer-value segments. The rule is:
#
# | Segment | Rule (order value `v` in €) |
# |---|---|
# | `micro` | v < 25 |
# | `standard` | 25 ≤ v ≤ 150 |
# | `premium` | 150 < v ≤ 500 |
# | `VIP` | v > 500 |
#
# Note the inclusive/exclusive boundaries carefully. A 150 € order is still `standard`; a 150.01 € order is already `premium`. This kind of boundary decision is exactly the sort of thing that ends up in a product requirements document — and the sort of thing a data analyst has to encode correctly.

# %% [markdown]
# ## Task 1 — Classify each order
#
# Write a `for` loop that goes through `order_values`. For each value, print a line like:
#
# ```
# 12.50 € → micro
# 189.75 € → premium
# ```

# %%
# TODO: loop + if/elif/else + print

# %% [markdown]
# ## Task 2 — Count how many orders in each segment
#
# Build a `counts` dictionary with the four segments as keys. At the end, print the dictionary.
#
# This is exactly what you would show a marketing lead who asks: *"How is our customer base distributed across value tiers?"*

# %%
# TODO: counts dict + loop + segment increment

# %% [markdown]
# ## Task 3 — Average basket size of the high-value orders
#
# Compute the **mean** of only those order values that are strictly greater than 150 € (i.e. the `premium` and `VIP` segments combined). Print the result rounded to two decimal places.
#
# Hint: you can filter with a list comprehension `[v for v in order_values if v > 150]`, or with a classic loop — your choice.

# %%
# TODO: filter + mean + formatted print

# %% [markdown]
# ## Task 4 — Reflection (markdown, 3–5 sentences)
#
# Where did you use (or where *could you have used*) a **list comprehension** in this homework? Paste the line you wrote or would have written. If you didn't use one, explain why a classic loop felt easier — that is a fine answer and I want to know.

# %% [markdown]
# _Your reflection here._
