# %% [markdown]
# # Mini-Challenge 3 — Refactor a messy notebook into something exam-ready
# ### Saint Mary's · Friday lunch break
#
# > *"This works, but the board can't read it. Make it presentable."*
#
# **Time:** 15 min · **Mode:** solo · **Goal:** see what 'clean' looks like in practice.
#
# ---
#
# Below you'll find a notebook cell that "works". Refactor it according to the clean-notebook checklist:
#
# 1. Markdown title + one-line motivation
# 2. Setup cell (imports + data) — separate from analysis
# 3. Helper functions defined together
# 4. Each code cell has ONE job
# 5. Variables named for meaning (no `xx`, `tmp`, `z`)
# 6. Plot has title + labels
# 7. No commented-out dead code

# %% [markdown]
# ## Step 0 — Read the messy code, then run it once to confirm it works

# %%
# This cell is the entire 'analysis' you inherited. It works, but barely.
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

HERE = Path.cwd()
DATA = next((p / "data" for p in [HERE, *HERE.parents] if (p / "data").exists()), None)

# data
xx = pd.read_csv(DATA / "encounters.csv", parse_dates=["admission_date","discharge_date"])
yy = pd.read_csv(DATA / "drg_catalog.csv")

# print(xx.head())   # left from debugging

tmp = xx.merge(yy, on="drg_code", how="left")
tmp["m"] = tmp["base_reimbursement_eur"] - tmp["actual_cost_eur"]   # m = margin
# tmp["m2"] = tmp["m"] * 1.05  # not used anymore

z = tmp.groupby("ward")["m"].sum()
print(z)

# plot
fig, ax = plt.subplots()
z.plot(kind="bar", ax=ax)
plt.show()

# %% [markdown]
# ## Step 1 — Refactor
#
# Below, build the clean version across MULTIPLE cells. Use markdown headers between sections.

# %% [markdown]
# ### Setup

# %%
# TODO: imports and data loading. Nothing else here.

# %% [markdown]
# ### Compute margin per ward

# %%
# TODO: a small function that takes a DataFrame and returns margin per ward.
# def margin_by_ward(encounters_df, drg_df): ...

# %% [markdown]
# ### Visualise

# %%
# TODO: one cell that plots the result. Title, x-label, y-label.

# %% [markdown]
# ### Reflection

# %% [markdown]
# TODO: in this markdown cell, write 2-3 sentences:
# - What did the messy version hide?
# - What does the clean version make obvious?
# - One thing you would still improve.
