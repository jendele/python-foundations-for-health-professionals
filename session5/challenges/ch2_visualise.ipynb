# %% [markdown]
# # Mini-Challenge 2 — Visualise the loss-makers
# ### Saint Mary's · Friday morning, 11:25
#
# > *"In a chart she can read in 5 seconds: the top 10 loss-making DRGs at Saint Mary's. Title, axis labels, the works."*
#
# **Time:** 25 min · **Mode:** tandem · **Goal:** build one publication-ready bar chart.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

HERE = Path.cwd()
DATA = next((p / "data" for p in [HERE, *HERE.parents] if (p / "data").exists()), None)
assert DATA is not None, "data/ folder not found"

enc = pd.read_csv(DATA / "encounters.csv", parse_dates=["admission_date","discharge_date"])
drg = pd.read_csv(DATA / "drg_catalog.csv")
patients = pd.read_csv(DATA / "patients.csv")

# %% [markdown]
# ## Step 1 — Compute total margin per DRG

# %%
# Hint: same as challenge 1 but only the column we need.
# enc = enc.merge(drg, on="drg_code", how="left")
# enc["margin_eur"] = ...
# top_loss = enc.groupby("drg_code")["margin_eur"].sum().sort_values().head(10)

# %% [markdown]
# ## Step 2 — Build the chart

# %%
# TODO: build a horizontal bar chart with:
#   - title:  "Top 10 loss-making DRGs · Saint Mary's Q1 2026"
#   - x label: "Total margin (EUR)"
#   - y label: "DRG code"
#   - vertical line at 0
#   - figsize=(10, 6)

# fig, ax = plt.subplots(figsize=(10, 6))
# top_loss.plot(kind="barh", ax=ax, color="#c0392b")
# ax.set_title(...)
# ax.set_xlabel(...)
# ax.set_ylabel(...)
# ax.axvline(0, color="black", linewidth=1)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## ⭐ Fast-Track — Color-code and add break-even line

# %%
# TODO: include the top 5 BEST and top 5 WORST DRGs in the same chart.
# Color positive bars green ("#2e8b57") and negative bars red ("#c0392b").
# Add a vertical line at break-even (margin = 0).
